# %% [markdown]
# # CODE TO PERFORM SIMPLE LINEAR REGRESSION ON FUEL CONSUMPTION DATASET
# # Dr. Ryan @STEMplicity
# ![image.png](attachment:image.png)

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# <h1>this is the header</h1>
# <p>this is the pargaph</p>

# %% [markdown]
# # STEP #1: LIBRARIES IMPORT

# %%
import pandas as pd
import numpy as num
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # STEP #2: IMPORT DATASET

# %%
dataframe = pd.read_csv("IceCreamData.csv")
dataframe
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
dataframe.head(10)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194
# 5    14.352514  367.940744
# 6    13.707780  308.894518
# 7    30.833985  696.716640
# 8     0.976870   55.390338
# 9    31.669465  737.800824

# %%
dataframe.tail(10)
# Out:
#      Temperature     Revenue
# 490    23.824922  584.399945
# 491    34.472169  809.352519
# 492    23.056214  552.819351
# 493    14.931506  377.430928
# 494    25.112066  571.434257
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
dataframe.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %% [markdown]
# # STEP#3: VISUALIZE DATASET

# %%
sb.jointplot(x="Temperature",y="Revenue",color="black",data=dataframe)

# %%
sb.jointplot(x="Revenue",y="Temperature",color="blue",data=dataframe)

# %%
#pair plot feauture for the same data of icecream
#pair plot can make the comination of the plots(reduce two joinplot into one)

sb.pairplot(dataframe)

# %%
sb.lmplot(x="Temperature",y="Revenue",data=dataframe)

# %%
sb.lmplot(x="Revenue",y="Temperature",data=dataframe)

# %% [markdown]
# # STEP#4: CREATE TESTING AND TRAINING DATASET

# %%
dataframe
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
arr = dataframe[['Temperature']]
arr
# Out:
#      Temperature
# 0      24.566884
# 1      26.005191
# 2      27.790554
# 3      20.595335
# 4      11.503498
# ..           ...
# 495    22.274899
# 496    32.893092
# 497    12.588157
# 498    22.362402
# 499    28.957736
#
# [500 rows x 1 columns]

# %%
arr1 = dataframe['Revenue']
arr1
# Out:
# 0      534.799028
# 1      625.190122
# 2      660.632289
# 3      487.706960
# 4      316.240194
#           ...
# 495    524.746364
# 496    755.818399
# 497    306.090719
# 498    566.217304
# 499    655.660388
# Name: Revenue, Length: 500, dtype: float64

# %%
#use sklearn to divide ur data sets into two pieces of test and train

from sklearn.model_selection import train_test_split
x_train ,x_test,y_train,y_test = train_test_split(arr,arr1,test_size=0.25,random_state=42)
# x_train = x_train.to_numpy()
# y_train = y_train.to_numpy()
# x_test = x_test.to_numpy()

# x_train.reshape(-1,1)
# y_train.reshape(-1,1)
# x_test.reshape(-1,1)

# %%
x_train.shape
# Out:
# (375, 1)

# %%
y_train.shape
# Out:
# (375,)

# %%
x_test.shape
# Out:
# (125, 1)

# %%
list(x_train)
# Out:
# ['Temperature']

# %%
x_train.shape
# Out:
# (375, 1)

# %%
x_test.shape
# Out:
# (125, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
# x_train = [x_train]
# y_train =[y_train]
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("coeff :",regressor.coef_)
print("intercept :",regressor.intercept_)
# Out:
# coeff : [21.37416109]
# intercept : 46.910784750530695

# %% [markdown]
# # STEP#5: TRAIN THE MODEL

# %%
from sklearn.linear_model import LinearRegression
from numpy import array
reg = LinearRegression(fit_intercept=True)
# reg.fit(list(list(x_train)),list(list(y_train)))
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
reg.intercept_
# Out:
# 46.910784750530695

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression(fit_intercept=True)

# %%
# reg.fit(list(list(x_train)),list(list(y_train)))
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([21.37416109])

# %% [markdown]
# # STEP#6: TEST THE MODEL

# %%
y_predict = reg.predict(x_test)
y_predict
# Out:
# array([681.81277787, 632.03701584, 559.56236196, 498.84704992,
#        615.35775421, 304.73607431, 285.81302849, 315.61634521,
#        506.20253292, 685.57013845, 723.81902231, 400.82303176,
#        431.58187843, 671.24393513,  52.61827778, 198.8274425 ,
#        523.01806979, 563.82215553, 583.74570895, 682.11913736,
#        556.14851344, 783.72448213, 655.32484725, 569.988492  ,
#        912.00834943, 664.6281381 , 315.97207922, 630.90251298,
#        730.97303461, 697.89804173, 435.04880926, 471.17165448,
#        710.15811647, 799.64974714, 640.91056016, 493.60331223,
#        744.77578087, 318.11532407, 262.71809247, 132.11937313,
#        582.46776731, 230.44959759, 547.2212659 , 392.9861862 ,
#        436.63073379, 592.93436718, 572.00732982, 125.24002263,
#        474.74420892, 530.37968312, 623.08805407, 503.42063264,
#        484.54721484, 498.52811922, 551.14921878, 630.69921564,
#        573.04086113, 679.3611088 , 171.35825421, 660.37649129,
# ...

# %%
y_test
# Out:
# 361    659.873287
# 73     623.248701
# 374    559.135869
# 155    497.752318
# 104    627.901841
#           ...
# 220    563.301280
# 176    520.470310
# 320    374.955702
# 153    493.710333
# 231    449.112869
# Name: Revenue, Length: 125, dtype: float64

# %%
dataframe2 = pd.DataFrame()

# %%
plt.scatter(x_train,y_train,color="brown")

plt.plot(x_train,reg.predict(x_train),color="red")
plt.xlabel('Temperature[Degree C]')
plt.ylabel('Revenue[Dollars]')
plt.title("ice cream shop prediction of revenue on temperature")


plt.scatter(x_test,y_test,color="black")
plt.plot(x_test,reg.predict(x_test))
sb.lmplot(x="Temperature",y="Revenue",data=dataframe)

# %%
y_predict = reg.predict([[75]])
# Out:
# /home/sandy/.local/lib/python3.8/site-packages/sklearn/base.py:441: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_predict
# Out:
# array([1649.97286648])

# %% [markdown]
# # EXCELLENT JOB! NOW YOU BECAME EXPERT IN SIMPLE LINEAR REGRESSION

# %%
print("completed simple project ")
# Out:
# completed simple project
